# %% [markdown]
# ### Perceptron vs. Adaline vs. MultiLayerPerceptron (logistic sigmoid)

# %%
#!pip install mlxtend

# %%
# Importing python ml extension library and some more
from mlxtend.plotting import plot_decision_regions
from mlxtend.classifier import Perceptron, Adaline, MultiLayerPerceptron
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import matplotlib.gridspec as gridspec
import itertools

# %%
# Generating a grid and some nice moons
gs = gridspec.GridSpec(2, 2)
X, y = make_moons(n_samples=100, random_state=123)

# Initializing the different algorithms
ppn = Perceptron(epochs=50, eta=0.05, random_seed=0)
ada = Adaline(epochs=50, eta=0.05, random_seed=0)
mlp = MultiLayerPerceptron(hidden_layers=[50],
                            l2=0.00, 
                            l1=0.0, 
                            epochs=500, 
                            eta=0.08, 
                            momentum=0.0,
                            decrease_const=0.0,
                            minibatches=1,
                            random_seed=42,
                            print_progress=1)

# Fitting and plotting the algorithms
fig = plt.figure(figsize=(10,8))
for clf, lab, grd in zip([ppn, ppn, mlp],
                         ['Perceptron', 'Adaline', 'MLP (logistic sigmoid)'],
                         itertools.product([0, 1], repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
    plt.title(lab)

plt.show()
# Out:
# Iteration: 500/500 | Cost 0.11

# %%
from sklearn.datasets import make_circles

# This time with some circles
X, y = make_circles(n_samples=100, random_state=123)
fig = plt.figure(figsize=(10,8))
for clf, lab, grd in zip([ppn, ppn, mlp],
                         ['Perceptron', 'Adaline', 'MLP (logistic sigmoid)'],
                         itertools.product([0, 1], repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
    plt.title(lab)

plt.show()
# Out:
# Iteration: 500/500 | Cost 2.01C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
from sklearn.datasets import make_blobs

# This time with some circles
X, y = make_blobs(n_samples=100, random_state=123, centers=2)
fig = plt.figure(figsize=(10,8))
for clf, lab, grd in zip([ppn, ppn, mlp],
                         ['Perceptron', 'Adaline', 'MLP (logistic sigmoid)'],
                         itertools.product([0, 1], repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
    plt.title(lab)

plt.show()
# Out:
# Iteration: 500/500 Cost 32.21
